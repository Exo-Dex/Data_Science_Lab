# %% [markdown]
# <a href="https://colab.research.google.com/github/Exo-Dex/Data_Science_Lab/blob/main/Experiment-4/histograph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a normal distribution
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# Create the histogram
plt.hist(s, bins=50, density=True, alpha=0.6, color='g')

# probability density function (PDF)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = ((1 / (np.sqrt(2 * np.pi) * sigma) * np.exp(-0.5 * ((x - mu)/sigma)**2)))
plt.plot(x, p, 'k', linewidth=2)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of a Normal Distribution')
plt.grid(True)

# Show the plot
plt.show()
